# %%
import numpy as np
import pandas as pd
data = pd.read_csv('BollyBAIT.csv')[89:200]
data.head()
# Out:
#                                                 Title  \
# 89     Akshay Kumar New Full Action Hindi Movies 2021
# 90               Radhe Full Movie Leatest Movies 2020
# 91  Anthim full movie | Salman khan new movie | Di...
# 92  Radhe Official Trailer, Salman Khan, Disha Pat...
# 93  Radhe Official Trailer | Salman Khan | Randeep...
#
#                                      Translated Title     Video ID  \
# 89     Akshay Kumar New Full Action Hindi Movies 2021  vykdTWjc7hw
# 90               Radhe Full Movie Leatest Movies 2020  8k-eH6uS-E0
# 91  Anthim full movie | Salman khan new movie | Di...  9FRgxjOMEEc
# 92  Radhe Official Trailer, Salman Khan, Disha Pat...  XowwHgdiYsc
# 93  Radhe Official Trailer | Salman Khan | Randeep...  dT6PPuJEZmY
#
#                                       Video URL           Channel Title  \
# 89  https://www.youtube.com/watch?v=vykdTWjc7hw  Varsha Music Multiplex
# 90  https://www.youtube.com/watch?v=8k-eH6uS-E0          Multimedia Hub
# 91  https://www.youtube.com/watch?v=9FRgxjOMEEc              IMOVIE FAN
# 92  https://www.youtube.com/watch?v=XowwHgdiYsc             ZOOM MOVIES
# 93  https://www.youtube.com/watch?v=dT6PPuJEZmY             Lekhu Meena
#
#    Misleading Video False Promises  Exaggerated Video Spam Content   \
# 89               No             Yes                No            No
# 90               No             Yes                No            No
# 91               No             Yes                No            No
# 92               No             Yes               Yes            No
# 93               No             Yes                No            No
#
#    Exploits Curiosity Gap   ... Title Bert  758  Title Bert  759  \
# 89                      No  ...       -0.298777         0.118960
# 90                      No  ...       -0.089150        -0.353792
# 91                      No  ...       -0.534895         0.054757
# 92                      No  ...        0.020614        -0.384075
# 93                      No  ...       -0.328250         0.003646
#
#     Title Bert  760  Title Bert  761  Title Bert  762  Title Bert  763  \
# 89         0.423422         0.247452        -0.011898         0.769236
# 90         0.003876         0.176764        -0.406266         0.850577
# 91         0.217595        -0.385819         0.210733         0.758999
# 92         0.324811        -0.302744        -0.561439         0.315721
# 93         0.255994        -0.508601        -0.105255         0.490806
#
#     Title Bert  764  Title Bert  765  Title Bert  766  Title Bert  767
# 89         0.058276        -0.383291         0.195937        -0.610816
# 90        -0.156300        -0.401444         0.035265        -0.319510
# 91        -0.334091        -0.401273         0.192134        -0.442840
# 92        -0.560574        -0.710493        -0.018813        -0.205280
# 93        -0.319197        -0.586966        -0.039232        -0.329148
#
# [5 rows x 793 columns]

# %%
from pytube import YouTube
import urllib.request
import videokf as vf
for ind in data.index: 
    print(data['Title'][ind])
    name_tag = data['Video ID'][ind]
    #download youtube video
    youtube_video_url = data['Video URL'][ind]
    #"https://www.youtube.com/watch?v=" + name_tag
    folder_path = "/Users/peyamowar/Downloads/clickbait_youtube/bollybait/" + name_tag + "/"
    video_name = name_tag
    try:
        yt_obj = YouTube(youtube_video_url)
        filters = yt_obj.streams.filter(progressive = True, file_extension = 'mp4')
        filters.get_highest_resolution().download(output_path = folder_path, filename = video_name)
        print('Video Downloaded Successfully')
    except Exception as e:
        print("Error for Video: " + name_tag)
    #download video thumbnail
    thumbnail_path = "https://img.youtube.com/vi/" + name_tag + "/default.jpg"
    thumbnail_name = folder_path + name_tag + "_thumbnail.jpg"
    try:
        urllib.request.urlretrieve(thumbnail_path, thumbnail_name)
    except Exception as e:
        print(e)
    #extract video keyframes
    keyframe_path = folder_path + name_tag + ".mp4"
    try:
        vf.extract_keyframes(video_file = keyframe_path)
    except Exception as e:
        print(e)
# Out:
# Akshay Kumar New Full Action Hindi Movies 2021

# %% [markdown]
# '''
# BB Ki Vines (Vlog #1)- | BB in HK |
# DIWHY top All Reddit - 5 Minute Crafts - Needs to be STOPPED! #59 REDDIT REVIEW
#
# from youtube_dl import YoutubeDL
# audio_downloader = YoutubeDL({'format':'bestaudio'})
# audio_downloader.extract_info("https://www.youtube.com/watch?v=N2ntCdMggj0")
# import youtube_dl
# ydl_opts = {
#     'format': 'bestaudio/best',
#     'postprocessors': [{
#         'key': 'FFmpegExtractAudio',
#         'preferredcodec': 'wav',
#     }],
# }
# with youtube_dl.YoutubeDL(ydl_opts) as ydl:
#     ydl.download(['https://www.youtube.com/watch?v=N2ntCdMggj0'])
# '''
# import ffmpeg
# import os
# import speech_recognition as sr
# command2mp3 = "ffmpeg -i hello.mp4 hello.mp3"
# command2wav = "ffmpeg -i hello.mp3 hello.wav"
# os.system(command2mp3)
# os.system(command2wav)
# r = sr.Recognizer()
# with sr.AudioFile("hello.wav") as source:
#      audio = r.record(source, duration=120)
# print(r.recognize_google(audio))

# %% [markdown]
# #Python 2.x program to transcribe an Audio file
# import speech_recognition as sr
# from google_trans_new import google_translator
# translator = google_translator()
#
# AUDIO_FILE = ("[ONTIVA.COM]-Rakesh Tikait reacts to PM Modi's MSP statement in Rajya Sabha | ABP News-HQ.wav")
#
# # use the audio file as the audio source
#
# r = sr.Recognizer()
#
# with sr.AudioFile(AUDIO_FILE) as source:
#     #reads the audio file. Here we use record instead of
#     #listen
#     r.adjust_for_ambient_noise(source, duration=0.5)
#     audio1 = r.record(source, duration=15)
#     audio2 = r.record(source, duration=15)
#     audio3= r.record(source, duration=15)
#
# try:
#     s=r.recognize_google(audio1)
#     text1 = s
#     text1 = translator.translate(text1,lang_tgt='en')
#     print(text1)
#     t=r.recognize_google(audio2)
#     text2 = t
#     text2 = translator.translate(text2,lang_tgt='en')
#     print(text2)
#     f=r.recognize_google(audio3)
#     text3 = f
#     text3 = translator.translate(text3,lang_tgt='en')
#     print(text3)
#
# except sr.UnknownValueError:
#     print("Google Speech Recognition could not understand audio")
